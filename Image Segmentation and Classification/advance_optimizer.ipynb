# %% [markdown]
# # Advanced Optimizers using Fashion-MNIST
#
# **Author**: Tianxiang (Adam) Gao <br>
# **Course**: CSC 383/483: Applied Deep Learning <br>
# **Description**: In this assignment, you will investigate how different optimization algorithms affect the training dynamics and final performance of a neural network on the **Fashion-MNIST** dataset using the **Keras deep learning library**. The Fashion-MNIST dataset contains 70,000 grayscale images of clothing items (such as shirts, shoes, and bags), each of size 28×28 pixels across 10 categories.
#
# You will train a simple multilayer perceptron (MLP) model using several optimizers—**SGD**, **SGD with Momentum**, **RMSprop**, and **Adam**—while keeping the network architecture, data, and initialization fixed. By comparing their learning curves and test accuracies, you will gain intuition about how optimizer choice influences convergence speed, stability, and generalization.

# %% [markdown]
# ## Setup
#
# We will first import some useful libraries:
# - `numpy` for numerical operations (e.g., arrays, random sampling).
# - `keras` for loading the MNIST dataset and building deep learning models.
# - `keras.layers` provides the building blocks (dense layers, convolutional layers, activation functions, etc.) to design neural networks.
# - `matplotlib` for visualizing images and plotting graphs.

# %%
import numpy as np
import keras
from keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare the Data [5/5]
#
# 1. Use `keras.datasets.fashion_mnist.load_data()` to load the **Fashion-MNIST** training and testing sets.
# 2. Normalize all pixel values from integers in the range **[0, 255]** to floating-point numbers between **0 and 1**.
#
# **Note**:
# In contrast to **Assignment 1**, we **do not** use `np.expand_dims()` to add a channel dimension because MLPs operate on flattened feature vectors rather than image tensors. Similarly, we **do not** convert labels to one-hot encoding, since we will use the loss function `"sparse_categorical_crossentropy"`, which expects integer labels directly.

# %%
# load the Fashion-MNIST training and testing sets
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# normalize all pixels from integers to floating point numbers
x_train = x_train.astype('float') / 255
x_test = x_test.astype('float') / 255

print("x_train shape:", x_train.shape)
num_classes, input_shape = 10, x_train.shape[1:]
print("num_classes:", num_classes)
print("input_shape:", input_shape)
# Out:
# x_train shape: (60000, 28, 28)
# num_classes: 10
# input_shape: (28, 28)

# %% [markdown]
# ## Visualize the Data [5/5]
#
# 3. Randomly pick 9 images from the training set `x_train`. Display them in a 3×3 grid using Matplotlib (`plt.subplot`). For each image, show its corresponding digit label (from `y_train`) as the subplot title.

# %%
indices = np.random.choice(len(x_train), 9, replace=False)

plt.figure(figsize=(6, 6))
for i, idx in enumerate(indices):
    plt.subplot(3, 3, i + 1)
    # squeeze last channel back to 2D for grayscale display
    plt.imshow(np.squeeze(x_train[idx]))
    # show the integer label, not one-hot
    plt.title(y_train[idx])
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Build the Model [30/30]
#
# 4. Implement a helper function `make_model(num_classes, input_shape)` that returns a simple two-layer MLP built by `keras.Sequential` with the following layers:
#     - Input layer: accepts images of shape `input_shape`.
#     - Flatten layer: converts each 2D image into a 1D vector.
#     - Dense layer: fully connected layer with 128 hidden units and a `"sigmoid"` activation function.
#     - Output layer: fully connected layer with `num_classes` units (one for each digit 0–9) and `"softmax"` activation.
#
# 5. Create a `base_model` using your helper function and inspect the model by calling `model.summary()` to display the network architecture, output shapes, and number of parameters in each layer.
#
# 6. Save the `initial_weights` of the `base_model` for reuse in optimizer comparisons.

# %%
def make_model(num_classes, input_shape):
    model = keras.Sequential([
        layers.Input(input_shape),
        layers.Flatten(),
        layers.Dense(128, activation='sigmoid'),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

base_model = make_model(num_classes, input_shape)
base_model.summary()

initial_weights = base_model.get_weights()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Define Optimizer Function [10/10]
#
# 7. To easily switch between different optimization algorithms, we will define a helper function `get_optimizer(name, lr=1e-3)` that returns the corresponding Keras optimizer object based on its name. Implement the function with the following behavior:
#    - `"sgd"`: Standard **stochastic gradient descent (SGD)**.
#    - `"momentum"`: **SGD with momentum** (momentum = 0.9).
#    - `"rmsprop"`: **RMSprop** optimizer (adaptive learning rate).
#    - `"adam"`: **Adam** optimizer (adaptive learning rate + momentum).
#    - Raise a `ValueError` if the name is unknown.

# %%
def get_optimizer(name, lr=1e-3):
    if name == "sgd":
        return keras.optimizers.SGD(learning_rate=lr)
    elif name == 'momentum':
        return keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    elif name == 'rmsprop':
        return keras.optimizers.RMSprop(learning_rate=lr)
    elif name == 'adam':
        return keras.optimizers.Adam(learning_rate=lr)
    else:
        raise ValueError(f"Unknown optimizer: {name}")

# %% [markdown]
# ## Train and Compare Optimizers [30/30]
#
# 8. We will write a helper function `train(name, batch_size=128, epochs=20)` to train the model with a specified optimizer, then loop over several optimizers to collect their training histories for plotting:
#    - Recreate a fresh model via `make_model(...)`.
#    - **Reset** to the same `initial_weights` to ensure a fair start.
#    - Build the optimizer with `get_optimizer(name)`.
#    - `compile` with `loss="sparse_categorical_crossentropy"` and `metrics=["accuracy"]`.
#    - `fit` on `(x_train, y_train)` with `validation_data=(x_test, y_test)`.
#    - **Return** the `History` object.
#
# 9. **Compare optimizers**:
#    - Create a list `optimizers = ["sgd", "momentum", "rmsprop", "adam"]`.
#    - For each name, call `train(name, ...)` and store the returned history in a dictionary `histories[name]`.

# %%
def train(name, batch_size=128, epochs=20):
  model = make_model(num_classes, input_shape)
  model.set_weights(initial_weights)
  opt = get_optimizer(name)
  model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  print(f"\n===Training with {name}===")
  hist = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
  return hist

# %%
optimizers = ["sgd", "momentum", "rmsprop", "adam"]
histories = {}
for opt in optimizers:
  histories[opt] = train(opt)
# Out:
# ===Training with sgd===
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1150 - loss: 2.3380 - val_accuracy: 0.1658 - val_loss: 2.2151
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3442 - loss: 2.1538 - val_accuracy: 0.4919 - val_loss: 2.0954
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5484 - loss: 2.0425 - val_accuracy: 0.5763 - val_loss: 1.9912
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6058 - loss: 1.9426 - val_accuracy: 0.6136 - val_loss: 1.8966
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6300 - loss: 1.8517 - val_accuracy: 0.6360 - val_loss: 1.8103
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6483 - loss: 1.7686 - val_accuracy: 0.6494 - val_loss: 1.7316
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6602 - loss: 1.6929 - val_accuracy: 0.6638 - val_loss: 1.6597
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6703 - loss: 1.6237 - val_accuracy: 0.6733 - val_loss: 1.5942
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6803 - loss: 1.5606 - val_accuracy: 0.6814 - val_loss: 1.5345
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6873 - loss: 1.5031 - val_accuracy: 0.6894 - val_loss: 1.4800
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6948 - loss: 1.4507 - val_accuracy: 0.6941 - val_loss: 1.4304
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7004 - loss: 1.4029 - val_accuracy: 0.6986 - val_loss: 1.3851
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7049 - loss: 1.3591 - val_accuracy: 0.7033 - val_loss: 1.3437
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7092 - loss: 1.3191 - val_accuracy: 0.7071 - val_loss: 1.3057
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7129 - loss: 1.2823 - val_accuracy: 0.7100 - val_loss: 1.2709
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7165 - loss: 1.2485 - val_accuracy: 0.7123 - val_loss: 1.2388
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7190 - loss: 1.2174 - val_accuracy: 0.7134 - val_loss: 1.2092
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7209 - loss: 1.1886 - val_accuracy: 0.7153 - val_loss: 1.1818
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7229 - loss: 1.1619 - val_accuracy: 0.7173 - val_loss: 1.1564
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7252 - loss: 1.1371 - val_accuracy: 0.7196 - val_loss: 1.1328
#
# ===Training with momentum===
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5473 - loss: 1.8683 - val_accuracy: 0.6756 - val_loss: 1.4904
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7083 - loss: 1.2840 - val_accuracy: 0.7198 - val_loss: 1.1368
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7328 - loss: 1.0352 - val_accuracy: 0.7361 - val_loss: 0.9680
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7438 - loss: 0.9045 - val_accuracy: 0.7436 - val_loss: 0.8700
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7524 - loss: 0.8247 - val_accuracy: 0.7484 - val_loss: 0.8068
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7581 - loss: 0.7706 - val_accuracy: 0.7556 - val_loss: 0.7633
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7651 - loss: 0.7312 - val_accuracy: 0.7592 - val_loss: 0.7300
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7699 - loss: 0.7013 - val_accuracy: 0.7625 - val_loss: 0.7034
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7748 - loss: 0.6770 - val_accuracy: 0.7678 - val_loss: 0.6822
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7794 - loss: 0.6570 - val_accuracy: 0.7718 - val_loss: 0.6643
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7840 - loss: 0.6398 - val_accuracy: 0.7747 - val_loss: 0.6489
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7871 - loss: 0.6251 - val_accuracy: 0.7786 - val_loss: 0.6360
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7919 - loss: 0.6118 - val_accuracy: 0.7836 - val_loss: 0.6236
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7950 - loss: 0.6002 - val_accuracy: 0.7873 - val_loss: 0.6132
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7982 - loss: 0.5897 - val_accuracy: 0.7916 - val_loss: 0.6039
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8012 - loss: 0.5801 - val_accuracy: 0.7927 - val_loss: 0.5952
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8038 - loss: 0.5713 - val_accuracy: 0.7951 - val_loss: 0.5871
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8064 - loss: 0.5633 - val_accuracy: 0.7979 - val_loss: 0.5800
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8089 - loss: 0.5560 - val_accuracy: 0.7989 - val_loss: 0.5730
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8108 - loss: 0.5491 - val_accuracy: 0.8008 - val_loss: 0.5668
#
# ===Training with rmsprop===
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7837 - loss: 0.6628 - val_accuracy: 0.8171 - val_loss: 0.5088
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8423 - loss: 0.4436 - val_accuracy: 0.8383 - val_loss: 0.4498
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8538 - loss: 0.4043 - val_accuracy: 0.8457 - val_loss: 0.4263
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8623 - loss: 0.3811 - val_accuracy: 0.8528 - val_loss: 0.4018
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8688 - loss: 0.3642 - val_accuracy: 0.8566 - val_loss: 0.4010
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8737 - loss: 0.3503 - val_accuracy: 0.8580 - val_loss: 0.3973
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8778 - loss: 0.3391 - val_accuracy: 0.8628 - val_loss: 0.3855
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8805 - loss: 0.3293 - val_accuracy: 0.8678 - val_loss: 0.3677
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8849 - loss: 0.3195 - val_accuracy: 0.8624 - val_loss: 0.3823
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8866 - loss: 0.3124 - val_accuracy: 0.8710 - val_loss: 0.3600
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8892 - loss: 0.3050 - val_accuracy: 0.8716 - val_loss: 0.3548
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8913 - loss: 0.2972 - val_accuracy: 0.8668 - val_loss: 0.3601
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8942 - loss: 0.2916 - val_accuracy: 0.8744 - val_loss: 0.3458
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8955 - loss: 0.2857 - val_accuracy: 0.8722 - val_loss: 0.3545
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8978 - loss: 0.2800 - val_accuracy: 0.8693 - val_loss: 0.3525
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8996 - loss: 0.2744 - val_accuracy: 0.8707 - val_loss: 0.3524
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9018 - loss: 0.2693 - val_accuracy: 0.8712 - val_loss: 0.3465
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9032 - loss: 0.2634 - val_accuracy: 0.8795 - val_loss: 0.3402
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9047 - loss: 0.2595 - val_accuracy: 0.8838 - val_loss: 0.3256
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9075 - loss: 0.2548 - val_accuracy: 0.8781 - val_loss: 0.3390
#
# ===Training with adam===
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7809 - loss: 0.6939 - val_accuracy: 0.8206 - val_loss: 0.5089
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8444 - loss: 0.4445 - val_accuracy: 0.8422 - val_loss: 0.4451
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8578 - loss: 0.3995 - val_accuracy: 0.8466 - val_loss: 0.4229
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8669 - loss: 0.3735 - val_accuracy: 0.8553 - val_loss: 0.4023
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8733 - loss: 0.3557 - val_accuracy: 0.8569 - val_loss: 0.3937
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8773 - loss: 0.3410 - val_accuracy: 0.8637 - val_loss: 0.3833
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8816 - loss: 0.3293 - val_accuracy: 0.8636 - val_loss: 0.3872
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8868 - loss: 0.3180 - val_accuracy: 0.8714 - val_loss: 0.3577
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8900 - loss: 0.3062 - val_accuracy: 0.8686 - val_loss: 0.3655
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8918 - loss: 0.2987 - val_accuracy: 0.8725 - val_loss: 0.3507
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8950 - loss: 0.2901 - val_accuracy: 0.8756 - val_loss: 0.3441
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8978 - loss: 0.2835 - val_accuracy: 0.8763 - val_loss: 0.3440
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8993 - loss: 0.2770 - val_accuracy: 0.8745 - val_loss: 0.3485
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9017 - loss: 0.2691 - val_accuracy: 0.8791 - val_loss: 0.3375
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9040 - loss: 0.2623 - val_accuracy: 0.8822 - val_loss: 0.3318
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9061 - loss: 0.2576 - val_accuracy: 0.8843 - val_loss: 0.3280
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9089 - loss: 0.2515 - val_accuracy: 0.8815 - val_loss: 0.3287
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9104 - loss: 0.2464 - val_accuracy: 0.8829 - val_loss: 0.3289
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9120 - loss: 0.2409 - val_accuracy: 0.8794 - val_loss: 0.3343
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9144 - loss: 0.2363 - val_accuracy: 0.8859 - val_loss: 0.3240

# %% [markdown]
# ## Plot Training and Test Loss [10/10]
#
# 10. We will now visualize the **training and test loss curves** for all optimizers on a single plot. Write a function `plot_histories(histories, optimizers, log_scale=False)` that:
#    - Creates a new figure using `plt.figure(figsize=(8,5))`.
#    - Iterates through each optimizer in the list.
#    - Plots both **training loss** (solid line) and **test loss** (dashed line) for the same color.
#    - Adds axis labels, title, legend, and grid lines.
#    - Optionally uses a logarithmic y-axis if `log_scale=True` (use `plt.yscale("log")`).
#
# 11. Call the function twice:
#    - Once with the default linear scale.
#    - Once with `log_scale=True` to observe convergence differences in early epochs.

# %%
def plot_histories(histories, optimizers, log_scale=False):
    plt.figure(figsize=(8,5))
    colors = plt.cm.tab10.colors

    for i, opt in enumerate(optimizers):
        color = colors[i % len(colors)]
        plt.plot(histories[opt].history['loss'], ls='-', c=color, label=f'{opt} train')
        plt.plot(histories[opt].history['val_loss'], ls='--', c=color, label=f'{opt} val')

    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training vs Validation Loss (Different Optimizers)")
    plt.legend()
    plt.grid(True, which="both", ls=":")
    if log_scale:
        plt.yscale("log")
        plt.ylabel("Loss (log scale)")
    plt.show()

# Example calls
plot_histories(histories, optimizers)              # linear scale
plot_histories(histories, optimizers, log_scale=True)  # log scale

# %% [markdown]
# ## Interpretation and Discussion [10/10]
#
# Write a short reflection (3–5 sentences) interpreting your results.
#
# **Note**:
# Your explanation should focus on what you observe from the **training and validation curves** rather than theoretical definitions.
# Be concise but specific — mention patterns you can clearly see in your plots and test results.

# %% [markdown]
# From the loss curve plot, I can see that Adam and RMSProp drop much faster in the first few epochs, reaching a low training loss quickly, while SGD decreases more slowly and improves steadily across epochs. The addition of momentum shows that the loss drops earlier and more smoothly than just using SGD, but it still converges more slowly than Adam. On the validation curve, Adam/RMSProp reach a plateau earlier, and the training loss keeps falling while the validation loss either flattens (SGD/Momentum) or rises (Adam/RMSProp), which suggests the model is starting to overfit (especially when the validation loss rises).
